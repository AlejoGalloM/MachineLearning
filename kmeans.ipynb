# %% [markdown]
# <a href="https://colab.research.google.com/github/AlejoGalloM/MachineLearning/blob/master/kmeans.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2 
from skimage.io import imread
import numpy as np
import matplotlib.pyplot as plt

# %%
path='drive/MyDrive/data/'
image = cv2.imread(path+'montanas.jpg')

# %%
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(16,9))
plt.imshow(image)
plt.xticks([])
plt.yticks([])
# Out:
# ([], <a list of 0 Text major ticklabel objects>)

# %%
pixel_values = image.reshape(-1,3)
print(pixel_values.shape)

pixel_values = np.float32(pixel_values)
# Out:
# (614400, 3)

# %%
criteria = (cv2.TERM_CRITERIA_EPS+cv2.TERM_CRITERIA_MAX_ITER, 1000, 0.02)

k=3
_,labels, (centers) = cv2.kmeans(pixel_values, k, None, criteria, 10, cv2.KMEANS_RANDOM_CENTERS)

# %%
centers = np.uint8(centers)
print(centers)
# Out:
# [[ 21  30  18]
#  [225 163 138]
#  [ 89  90 116]]

# %%
labels = labels.flatten()
print (labels.shape)
# Out:
# (614400,)

# %%
segmented_image = centers[labels]
print(segmented_image.shape)
# Out:
# (614400, 3)

# %%
segmented_image = segmented_image.reshape(image.shape)
print(segmented_image.shape)

plt.figure(figsize=(16,9))
plt.imshow(segmented_image)
plt.xticks([])
plt.yticks([])
# Out:
# (640, 960, 3)
# ([], <a list of 0 Text major ticklabel objects>)
